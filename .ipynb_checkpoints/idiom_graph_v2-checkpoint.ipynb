# %%
import time

# %% [markdown]
# ### Load Data

# %%
# Parse the source
with open('dataset/THUOCL_chengyu.txt', 'r', encoding='utf-8') as source:
    idioms = [i for i in map(lambda x: x.split()[0], source.readlines()) if len(i) <= 4]

nodes = set([i[0] for i in idioms] + [i[-1] for i in idioms])
edges = [{"src": i[0], "dst": i[-1], "idiom": i} for i in idioms]

# %% [markdown]
# #### Create Graph

# %%
from py2neo import Graph
graph = Graph("bolt://localhost:7687", password="12345678")

cql = "CREATE \n" + ",".join("(%s : Node {char: \"%s\"})\n"%(n, n) for n in nodes)
for e in edges:
    cql += ",(%s)-[:idiom {idiom: '%s'}]->(%s)\n"%(e['src'], e["idiom"], e['dst'])

start = time.time()
graph.run("match (n) detach delete n")
graph.run(cql)
print("created graph, time elapsed: %.2fs"%(time.time() - start))
# Out:
# created graph, time elapsed: 8.86s

# %% [markdown]
# ___
# ### Query Graph
# ##### Find next word

# %%
next_word = lambda word: graph.run("match ()-[:idiom {idiom: '%s'}]->()-[e:idiom]->() return e.idiom"%word)

df_next = next_word("坚定不移").to_data_frame()

print("found %i idioms"%len(df_next))
df_next.head()
# Out:
# found 3 idioms
#   e.idiom
# 0    移风易俗
# 1    移山填海
# 2    移花接木

# %% [markdown]
# ##### Find path

# %%
def find_path(idiom, length, limit):
    cql = "match ()-[e:idiom {idiom: '%s'}]->()"%idiom
    path = "".join(["-[e%i:idiom]->()"%i for i in range(length)])
    ret = ", ".join(["e%i.idiom"%i for i in range(length)])
    return graph.run(cql + path + " return e.idiom, " + ret + " limit %i"%limit).to_data_frame()

# %%
start = time.time()
df_paths = find_path(idiom="坚定不移", length=5, limit=100000)

print("found %i paths, time elapsed: %.2fs"%(len(df_paths), time.time() - start))
df_paths.head(10)
# Out:
# found 6833 paths, time elapsed: 0.22s
#   e.idiom e0.idiom e1.idiom e2.idiom e3.idiom e4.idiom
# 0    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返
# 1    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流言蜚语
# 2    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流芳百世
# 3    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流年似水
# 4    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流水无情
# 5    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流落他乡
# 6    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流芳千古
# 7    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流水行云
# 8    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流离颠沛
# 9    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流离失所

# %%
start = time.time()
df_paths = find_path(idiom="坚定不移", length=10, limit=100000)

print("found %i paths, time elapsed: %.2fs"%(len(df_paths), time.time() - start))
df_paths.to_csv("output/坚定不移.csv", index=False)
df_paths.head(10)
# Out:
# found 100000 paths, time elapsed: 8.25s
#   e.idiom e0.idiom e1.idiom e2.idiom e3.idiom e4.idiom e5.idiom e6.idiom  \
# 0    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 1    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 2    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 3    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 4    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 5    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 6    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 7    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 8    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
# 9    坚定不移     移山填海     海底捞针     针锋相对     对答如流     流连忘返     返璞归真     真枪实弹
#
#   e7.idiom e8.idiom e9.idiom
# 0     弹尽援绝     绝顶聪明     明目张胆
# 1     弹尽援绝     绝顶聪明     明心见性
# 2     弹尽援绝     绝顶聪明     明察暗访
# 3     弹尽援绝     绝顶聪明     明升暗降
# 4     弹尽援绝     绝顶聪明     明日黄花
# 5     弹尽援绝     绝顶聪明     明哲保身
# 6     弹尽援绝     绝顶聪明     明珠暗投
# 7     弹尽援绝     绝顶聪明     明眸善睐
# 8     弹尽援绝     绝顶聪明     明眸皓齿
# 9     弹尽援绝     绝顶聪明     明德惟馨
